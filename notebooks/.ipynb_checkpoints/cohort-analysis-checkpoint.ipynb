# %% [markdown]
# # Import Libraries and packages

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(
    { "figure.figsize": (8, 5) },
    style='ticks',
    color_codes=True,
    font_scale=1
)
# %config InlineBackend.figure_format = 'retina'

# Ignore warnings
import warnings
warnings.filterwarnings('ignore')

# !pip install category_encoders -q
# !pip install xgboost

# ML utilities
from sklearn.model_selection import train_test_split, StratifiedShuffleSplit, KFold, cross_val_score
from sklearn.preprocessing import StandardScaler, MinMaxScaler, LabelEncoder
from sklearn import metrics

# Models
import xgboost as xgb
from xgboost import XGBClassifier
from sklearn.tree import DecisionTreeClassifier, export_text
from sklearn.ensemble import RandomForestClassifier
from sklearn.cluster import KMeans

# Encoding and metrics
from category_encoders import TargetEncoder
from sklearn.metrics import accuracy_score, balanced_accuracy_score, confusion_matrix, classification_report

# Hyperparameter tuning
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
# Out:
# Requirement already satisfied: xgboost in c:\users\lapt\anaconda3\lib\site-packages (3.0.0)
# Requirement already satisfied: numpy in c:\users\lapt\anaconda3\lib\site-packages (from xgboost) (1.26.4)
# Requirement already satisfied: scipy in c:\users\lapt\anaconda3\lib\site-packages (from xgboost) (1.13.1)

# %% [markdown]
# # Loading the dataset

# %%
ecom_data = pd.read_csv("../data/Dataset_ecommerce.csv")

# %% [markdown]
# # Initial inspection of the dataset

# %%
ecom_data.head()
# Out:
#   InvoiceNo          InvoiceDate  CustomerID StockCode  Description  Quantity  \
# 0    536365  2010-12-01 08:26:00     17850.0    SC1734  Electronics        65
# 1    536365  2010-12-01 08:26:00     17850.0    SC2088    Furniture        95
# 2    536365  2010-12-01 08:26:00     17850.0    SC3463        Books        78
# 3    536365  2010-12-01 08:26:00     17850.0    SC6228         Toys        15
# 4    536365  2010-12-01 08:26:00     17850.0    SC2149         Toys        50
#
#    UnitPrice       Country
# 0      10.23         Egypt
# 1      19.61          Mali
# 2      61.49          Mali
# 3      24.73  South Africa
# 4      38.83        Rwanda

# %%
ecom_data.sample()
# Out:
#        InvoiceNo          InvoiceDate  CustomerID StockCode Description  \
# 518741    580115  2011-12-01 16:22:00         NaN    SC8873       Books
#
#         Quantity  UnitPrice Country
# 518741        93      25.71    Togo

# %%
ecom_data.shape
# Out:
# (541909, 8)

# %%
ecom_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   InvoiceDate  541909 non-null  object
#  2   CustomerID   406829 non-null  float64
#  3   StockCode    541909 non-null  object
#  4   Description  541909 non-null  object
#  5   Quantity     541909 non-null  int64
#  6   UnitPrice    541909 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 33.1+ MB

# %% [markdown]
# ### Observation: Sampled Dataset contains 541909 rows and 8 columns in which most of them are strings.

# %%
ecom_data.describe(include='all')
# Out:
#        InvoiceNo          InvoiceDate     CustomerID StockCode  \
# count     541909               541909  406829.000000    541909
# unique     25900                23260            NaN      9000
# top       573585  2011-10-31 14:41:00            NaN    SC2014
# freq        1114                 1114            NaN        96
# mean         NaN                  NaN   15287.690570       NaN
# std          NaN                  NaN    1713.600303       NaN
# min          NaN                  NaN   12346.000000       NaN
# 25%          NaN                  NaN   13953.000000       NaN
# 50%          NaN                  NaN   15152.000000       NaN
# 75%          NaN                  NaN   16791.000000       NaN
# max          NaN                  NaN   18287.000000       NaN
#
#              Description       Quantity      UnitPrice        Country
# count             541909  541909.000000  541909.000000         541909
# unique                10            NaN            NaN             28
# top     Sports Equipment            NaN            NaN  Cote d'Ivoire
# freq               54765            NaN            NaN          19651
# mean                 NaN      50.534748      50.476354            NaN
# std                  NaN      28.849367      28.564775            NaN
# min                  NaN       1.000000       1.000000            NaN
# 25%                  NaN      26.000000      25.750000            NaN
# 50%                  NaN      51.000000      50.430000            NaN
# 75%                  NaN      76.000000      75.180000            NaN
# max                  NaN     100.000000     100.000000            NaN

# %%
# Checking Unique values in the columns
print("Unique Customers:", ecom_data['CustomerID'].nunique())
print("Unique Products:", ecom_data['StockCode'].nunique())
print("Countries:", ecom_data['Country'].nunique())
# Out:
# Unique Customers: 4372
# Unique Products: 9000
# Countries: 28

# %%
ecom_data.isnull().sum()
# Out:
# InvoiceNo           0
# InvoiceDate         0
# CustomerID     135080
# StockCode           0
# Description         0
# Quantity            0
# UnitPrice           0
# Country             0
# dtype: int64

# %% [markdown]
# ### Observation - The CustomerID column have 135080 null values (missing data).

# %% [markdown]
# # Splitting the features to qualitative and quantitative features

# %%
# Categorising quantitative features (numerical columns)
numerical_features = ecom_data.select_dtypes(include=['float64', 'int64']).columns.tolist()
# Categorising qualitative features (categorical columns)
categorical_features = ecom_data.select_dtypes(include=['object', 'bool']).columns.tolist()

# %%
numerical_features
# Out:
# ['CustomerID', 'Quantity', 'UnitPrice']

# %%
categorical_features
# Out:
# ['InvoiceNo', 'InvoiceDate', 'StockCode', 'Description', 'Country']

# %% [markdown]
# # Data Cleaning & Preprocessing

# %% [markdown]
# ## Handling missing values, duplicate values and formatting the CustomerID and InvoiceDate

# %%
# the percentage of missing values in each columns
missing_pct = round(ecom_data.isna().sum()/len(ecom_data) * 100, 1)
print(missing_pct)
# Out:
# InvoiceNo       0.0
# InvoiceDate     0.0
# CustomerID     24.9
# StockCode       0.0
# Description     0.0
# Quantity        0.0
# UnitPrice       0.0
# Country         0.0
# dtype: float64

# %% [markdown]
# ### Observation - ~25% of the CustomerID values are missing which is a significant portion of the dataset. However, since the goal of the project is churn prediction, it is better to drop rows with missing CustomerID in order to have a clean base of identifiable customers for all the cohort and ML modeling tasks.

# %%
# Drop rows with missing CustomerID
ecom_data = ecom_data.dropna(subset=['CustomerID'])

# %%
# Confirm if the missing CustomerID are dropped
print(f"Remaining rows: {ecom_data.shape[0]}")
print(f"Missing CustomerID after drop: {ecom_data['CustomerID'].isna().sum()}")
# Out:
# Remaining rows: 406829
# Missing CustomerID after drop: 0

# %%
# Check number of duplicates before dropping
duplicate_count = ecom_data.duplicated().sum()
print(f"Number of duplicate rows: {duplicate_count}")
# Out:
# Number of duplicate rows: 0

# %%
# Convert the CustomerID from float to integer
ecom_data = ecom_data.dropna(subset=['CustomerID'])
ecom_data['CustomerID'] = ecom_data['CustomerID'].astype(int)

# %%
# Convert the date format from string to datetime
ecom_data['InvoiceDate'] = pd.to_datetime(ecom_data['InvoiceDate'])

# %%
# check the range of dates
print(ecom_data['InvoiceDate'].min(), "to", ecom_data['InvoiceDate'].max())
# Out:
# 2010-12-01 08:26:00 to 2011-12-09 12:50:00

# %% [markdown]
# # Feature engineering based on domain knowledge

# %%
# Create TotalPrice feature
ecom_data['TotalPrice'] = ecom_data['Quantity'] * ecom_data['UnitPrice']

# %%
# Extract features such as Invoice Year, Invoice Month and Weekday
ecom_data['InvoiceYear'] = ecom_data['InvoiceDate'].dt.year
ecom_data['InvoiceMonth'] = ecom_data['InvoiceDate'].dt.to_period('M')
ecom_data['Weekday'] = ecom_data['InvoiceDate'].dt.day_name()

# %%
ecom_data.head(1)
# Out:
#   InvoiceNo         InvoiceDate  CustomerID StockCode  Description  Quantity  \
# 0    536365 2010-12-01 08:26:00       17850    SC1734  Electronics        65
#
#    UnitPrice Country  TotalPrice  InvoiceYear InvoiceMonth    Weekday
# 0      10.23   Egypt      664.95         2010      2010-12  Wednesday
